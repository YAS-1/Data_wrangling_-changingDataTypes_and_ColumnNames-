# %% [markdown]
# # **Hands-on Practice Lab: Data Wrangling**
#
#
# In this lab, you will use the skills acquired in data wrangling & pre-processing and address the issues of handling missing data, correct the data type of the dataframe attribute and execute the processes of data standardization and data normalization on specific attributes of the dataset.

# %% [markdown]
# # Objectives
#
# After completing this lab you will be able to:
#
#  - Handle missing data in different ways
#  - Correct the data type of different data values as per requirement
#  - Standardize and normalize the appropriate data attributes
#  - Visualize the data as grouped bar graph using Binning
#  - Converting a categorical data into numerical indicator variables

# %% [markdown]
# # Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# * `skillsnetwork` to download the dataset
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for mathematical operations.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) for additional plotting tools.

# %% [markdown]
# ### Importing Required Libraries
#
# _recommended that you import all required libraries in one place:_

# %% [markdown]
# ## ROOM 3 MEMBERS
# # Yawe Arthur
#
# # Mokili Promise
#
# # Philip Asingura
#
# # Isaac Nziriga

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
file_path= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"

# %%
Room3 = pd.read_csv("laptops.csv")
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %% [markdown]
# First we load data into a `pandas.DataFrame`:

# %%
#filepath = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-Coursera/laptop_pricing_dataset_mod1.csv"
#df = pd.read_csv(filepath, header=None)

# %% [markdown]
# Verify loading by displaying the dataframe summary using `dataframe.info()`

# %%
print(Room3.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       233 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB
# None

# %%
Room3.shape
# Out:
# (238, 13)

# %% [markdown]
# View the first 5 values of the updated dataframe using `dataframe.head()`

# %%
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0          35.560            1.6       8             256       1.60    978
# 1          39.624            2.0       4             256       2.20    634
# 2          39.624            2.7       8             256       2.20    946
# 3          33.782            1.6       8             128       1.22   1244
# 4          39.624            1.8       8             256       1.91    837

# %% [markdown]
# Note that we can update the `Screen_Size_cm` column such that all values are rounded to nearest 2 decimal places by using `numpy.round()`

# %%
Room3[['Screen_Size_cm']] = np.round(Room3[['Screen_Size_cm']],2)
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %% [markdown]
# # Task - 1
#
# ### Evaluate the dataset for missing data
# Missing data was last converted from '?' to numpy.NaN. Pandas uses NaN and Null values interchangeably. This means, you can just identify the entries having Null values. Write a code that identifies which columns have missing data.

# %%
# Write your code below and press Shift+Enter to execute 
Room3.isna().sum()
# Out:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    4
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         5
# Price             0
# dtype: int64

# %% [markdown]
# # Task - 2
#
# ### Replace with mean
# Missing values in attributes that have continuous data are best replaced using Mean value. We note that values in "Weight_kg" attribute are continuous in nature, and some values are missing. Therefore, write a code to replace the missing values of weight with the average value of the attribute.

# %%
Room3["Weight_kg"].mean()
# Out:
# 1.8622317596566522

# %%
#Write your code below and press Shift+Enter to execute

Room3["Weight_kg"].replace(np.NaN,Room3["Weight_kg"].mean(axis=0),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25144\741680586.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Room3["Weight_kg"].replace(np.NaN,Room3["Weight_kg"].mean(axis=0),inplace=True)

# %%
Room3.isna().sum()
# Out:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    4
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         0
# Price             0
# dtype: int64

# %%
Room3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  234 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       238 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %% [markdown]
# ### Replace with the most frequent value
# Missing values in attributes that have categorical data are best replaced using the most frequent value. We note that values in "Screen_Size_cm" attribute are categorical in nature, and some values are missing. Therefore, write a code to replace the missing values of Screen Size with the most frequent value of the attribute.

# %%
Room3['Screen_Size_cm'].mode()
# Out:
# 0    39.62
# Name: Screen_Size_cm, dtype: float64

# %%
# Write your code below and press Shift+Enter to execute

Room3["Screen_Size_cm"].replace(np.NaN,Room3["Screen_Size_cm"].mode()[0],inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_25144\396728292.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Room3["Screen_Size_cm"].replace(np.NaN,Room3["Screen_Size_cm"].mode()[0],inplace=True)

# %%
Room3.isna().sum()
# Out:
# Unnamed: 0        0
# Manufacturer      0
# Category          0
# Screen            0
# GPU               0
# OS                0
# CPU_core          0
# Screen_Size_cm    0
# CPU_frequency     0
# RAM_GB            0
# Storage_GB_SSD    0
# Weight_kg         0
# Price             0
# dtype: int64

# %%
Room3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  238 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       238 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %% [markdown]
# # Task - 3
#
# ### Fixing the data types
# Both "Weight_kg" and "Screen_Size_cm" are seen to have the data type "Object", while both of them should be having a data type of "float". Write a code to fix the data type of these two columns.

# %%
# Write your code below and press Shift+Enter to execute
Room3[["Weight_kg","Screen_Size_cm"]].astype("float")
# Out:
#      Weight_kg  Screen_Size_cm
# 0         1.60           35.56
# 1         2.20           39.62
# 2         2.20           39.62
# 3         1.22           33.78
# 4         1.91           39.62
# ..         ...             ...
# 233       1.70           35.56
# 234       1.20           33.78
# 235       1.36           30.48
# 236       2.40           39.62
# 237       1.95           35.56
#
# [238 rows x 2 columns]

# %%
Room3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      238 non-null    int64
#  1   Manufacturer    238 non-null    object
#  2   Category        238 non-null    int64
#  3   Screen          238 non-null    object
#  4   GPU             238 non-null    int64
#  5   OS              238 non-null    int64
#  6   CPU_core        238 non-null    int64
#  7   Screen_Size_cm  238 non-null    float64
#  8   CPU_frequency   238 non-null    float64
#  9   RAM_GB          238 non-null    int64
#  10  Storage_GB_SSD  238 non-null    int64
#  11  Weight_kg       238 non-null    float64
#  12  Price           238 non-null    int64
# dtypes: float64(3), int64(8), object(2)
# memory usage: 24.3+ KB

# %%
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %% [markdown]
# # Task - 4
#
# ### Data Standardization
# The value of Screen_size usually has a standard unit of inches. Similarly, weight of the laptop is needed to be in pounds. Use the below mentioned units of conversion and write a code to modify the columns of the dataframe accordingly. Update their names as well.
#
# ```{math}
# 1 inch = 2.54 cm
# 1 kg   = 2.205 pounds
# ```

# %%
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0           35.56            1.6       8             256       1.60    978
# 1           39.62            2.0       4             256       2.20    634
# 2           39.62            2.7       8             256       2.20    946
# 3           33.78            1.6       8             128       1.22   1244
# 4           39.62            1.8       8             256       1.91    837

# %%
Room3["Screen_Size_cm"] = Room3["Screen_Size_cm"] / 2.54

Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_cm  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0       14.000000            1.6       8             256       1.60    978
# 1       15.598425            2.0       4             256       2.20    634
# 2       15.598425            2.7       8             256       2.20    946
# 3       13.299213            1.6       8             128       1.22   1244
# 4       15.598425            1.8       8             256       1.91    837

# %%
Room3 = Room3.rename(columns={"Screen_Size_cm":"Screen_Size_inch"})

Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0         14.000000            1.6       8             256       1.60    978
# 1         15.598425            2.0       4             256       2.20    634
# 2         15.598425            2.7       8             256       2.20    946
# 3         13.299213            1.6       8             128       1.22   1244
# 4         15.598425            1.8       8             256       1.91    837

# %%
Room3["Weight_kg"] = Room3["Weight_kg"] * 2.205

Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_kg  Price
# 0         14.000000            1.6       8             256    3.52800    978
# 1         15.598425            2.0       4             256    4.85100    634
# 2         15.598425            2.7       8             256    4.85100    946
# 3         13.299213            1.6       8             128    2.69010   1244
# 4         15.598425            1.8       8             256    4.21155    837

# %%
Room3 = Room3.rename(columns={"Weight_kg":"Weight_pounds"})

Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000            1.6       8             256        3.52800
# 1         15.598425            2.0       4             256        4.85100
# 2         15.598425            2.7       8             256        4.85100
# 3         13.299213            1.6       8             128        2.69010
# 4         15.598425            1.8       8             256        4.21155
#
#    Price
# 0    978
# 1    634
# 2    946
# 3   1244
# 4    837

# %% [markdown]
# ### Data Normalization
# Often it is required to normalize a continuous data attribute. Write a code to normalize the "CPU_frequency" attribute with respect to the maximum value available in the dataset.

# %%
# Write your code below and press Shift+Enter to execute

Room3['CPU_frequency_NORMALIZED'] = Room3['CPU_frequency']/Room3['CPU_frequency'].max()

# %%
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category     Screen  GPU  OS  CPU_core  \
# 0           0         Acer         4  IPS Panel    2   1         5
# 1           1         Dell         3    Full HD    1   1         3
# 2           2         Dell         3    Full HD    1   1         7
# 3           3         Dell         4  IPS Panel    2   1         5
# 4           4           HP         4    Full HD    2   1         7
#
#    Screen_Size_inch  CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  \
# 0         14.000000            1.6       8             256        3.52800
# 1         15.598425            2.0       4             256        4.85100
# 2         15.598425            2.7       8             256        4.85100
# 3         13.299213            1.6       8             128        2.69010
# 4         15.598425            1.8       8             256        4.21155
#
#    Price  CPU_frequency_NORMALIZED
# 0    978                  0.551724
# 1    634                  0.689655
# ...

# %% [markdown]
# # Task - 5
#
# ### Binning
# Binning is a process of creating a categorical attribute which splits the values of a continuous data into a specified number of groups. In this case, write a code to create 3 bins for the attribute "Price". These bins would be named "Low", "Medium" and "High". The new attribute will be named "Price-binned".

# %%
# Write your code below and press Shift+Enter to execute
Room3["Price"]=Room3["Price"].astype(int, copy=True)

# %%
bins = np.linspace(min(Room3["Price"]), max(Room3["Price"]), 4)
bins
# Out:
# array([ 527.        , 1621.33333333, 2715.66666667, 3810.        ])

# %%
group_names = ['Low', 'Medium', 'High']

# %%
Room3['Price-binned'] = pd.cut(Room3['Price'], bins, labels=group_names, include_lowest=True )
Room3[['Price','Price-binned']].head(20)
# Out:
#     Price Price-binned
# 0     978          Low
# 1     634          Low
# 2     946          Low
# 3    1244          Low
# 4     837          Low
# 5    1016          Low
# 6    1117          Low
# 7     866          Low
# 8     812          Low
# 9    1068          Low
# 10    975          Low
# 11    558          Low
# 12    527          Low
# 13   1117          Low
# 14   1195          Low
# 15    876          Low
# 16   1213          Low
# 17   1105          Low
# 18   1392          Low
# 19   1092          Low

# %% [markdown]
# Also, plot the bar graph of these bins.

# %%
Price_Bin_count = Room3["Price-binned"].value_counts()

Price_Bin_count
# Out:
# Price-binned
# Low       160
# Medium     72
# High        6
# Name: count, dtype: int64

# %%
# Write your code below and press Shift+Enter to execute
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot


pyplot.bar(group_names, Price_Bin_count)
plt.pyplot.xlabel("Price")
plt.pyplot.ylabel("Price Bin count")
plt.pyplot.title("Price bins")
# Out:
# Text(0.5, 1.0, 'Price bins')

# %% [markdown]
# # Task - 6
#
# ### Indicator variables
# Convert the "Screen" attribute of the dataset into 2 indicator variables, "Screen-IPS_panel" and "Screen-Full_HD". Then drop the "Screen" attribute from the dataset.

# %%
# Write your code below and press Shift+Enter to execute

dummies = pd.get_dummies(Room3["Screen"])


dummies = dummies.rename(columns={'Full HD':'Screen-Full_HD', 'IPS Panel':'Screen-IPS_panel'})

dummies.head()
# Out:
#    Screen-Full_HD  Screen-IPS_panel
# 0           False              True
# 1            True             False
# 2            True             False
# 3           False              True
# 4            True             False

# %%
Room3 = pd.concat([Room3, dummies], axis=1)

# drop original column "fuel-type" from "df"
Room3.drop("Screen", axis = 1, inplace=True)

# %% [markdown]
# This version of the dataset, now finalized, is the one you'll be using in all subsequent modules.

# %% [markdown]
# Print the content of dataframe.head() to verify the changes that were made to the dataset.

# %%
Room3.head()
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  \
# 0           0         Acer         4    2   1         5         14.000000
# 1           1         Dell         3    1   1         3         15.598425
# 2           2         Dell         3    1   1         7         15.598425
# 3           3         Dell         4    2   1         5         13.299213
# 4           4           HP         4    2   1         7         15.598425
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price  \
# 0            1.6       8             256        3.52800    978
# 1            2.0       4             256        4.85100    634
# 2            2.7       8             256        4.85100    946
# 3            1.6       8             128        2.69010   1244
# 4            1.8       8             256        4.21155    837
#
#    CPU_frequency_NORMALIZED Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %%
print(Room3.head())
# Out:
#    Unnamed: 0 Manufacturer  Category  GPU  OS  CPU_core  Screen_Size_inch  \
# 0           0         Acer         4    2   1         5         14.000000
# 1           1         Dell         3    1   1         3         15.598425
# 2           2         Dell         3    1   1         7         15.598425
# 3           3         Dell         4    2   1         5         13.299213
# 4           4           HP         4    2   1         7         15.598425
#
#    CPU_frequency  RAM_GB  Storage_GB_SSD  Weight_pounds  Price  \
# 0            1.6       8             256        3.52800    978
# 1            2.0       4             256        4.85100    634
# 2            2.7       8             256        4.85100    946
# 3            1.6       8             128        2.69010   1244
# 4            1.8       8             256        4.21155    837
#
#    CPU_frequency_NORMALIZED Price-binned  Screen-Full_HD  Screen-IPS_panel
# ...

# %% [markdown]
# # END
#
# # Thank you for listening

# %% [markdown]
# <!--## Change Log

# %% [markdown]
# <!--|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-09-15|0.1|Abhishek Gagneja|Initial Version Created|
# |2023-09-19|0.2|Vicky Kuo|Reviewed and Revised| --!>
